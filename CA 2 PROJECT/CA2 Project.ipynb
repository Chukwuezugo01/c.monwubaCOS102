# %%
00}%", font=("Times New Roman", 14))
    discount_label.grid(row=3, column=0)

    discounted_label = Label(orderdetails_window, text=f"Total billings after discount: N{bill_discount}", font=("Times New Roman", 14))
    discounted_limport tkinter as tk
from tkinter import *

def submit_order():

    user_name = user_entry.get()
    Total_Billing = menu_totalcalculation()

    if Total_Billing > 1000 and Total_Billing < 2500:
        discount = 0.1
    elif Total_Billing > 2500 and Total_Billing < 5000:
        discount = 0.15
    elif Total_Billing > 5000:
        discount = 0.25
    elif Total_Billing < 1000:
        discount = 0

    bill_discount = Total_Billing - (Total_Billing * discount)

    orderdetails_window = Toplevel()
    orderdetails_window.title("Order Details")
    orderdetails_window.geometry("400x300")

    user_label = Label(orderdetails_window, text=f"Customer Name: {user_name}", font=("Times New Roman", 14))
    user_label.grid(row=0, column=0, pady=5)

    billings_label = Label(orderdetails_window, text=f"Your total billings are: N{Total_Billing}", font=("Times New Roman", 14))
    billings_label.grid(row=2, column=0)

    discount_label = Label(orderdetails_window, text=f"Your Discount is : {discount * 1abel.grid(row=4, column = 0)
def menu_totalcalculation():

    JollofRice_Total = int(JollofRice_sb.get()) * 350
    CoconutRice_Total = int(CoconutRice_sb.get()) * 350
    JollofSpaghetti_Total = int(JollofSpaghetti_sb.get()) * 350
    SavouryBeans_Total = int(SavouryBeans_sb.get()) * 350
    RoastedSweetPotatoes_Total = int(RoastedSweetPotatoes_sb.get()) * 300
    FriedPlantain_Total = int(FriedPlantain_sb.get()) * 150
    MixedVegetableSalad_Total = int(MixedVegetableSalad_sb.get()) * 150
    BoiledYam_Total = int(BoiledYam_sb.get()) * 150
    Eba_Total = int(Eba_sb.get()) * 100
    PoundedYam_Total = int(PoundedYam_sb.get()) * 100
    Semo_Total = int(Semo_sb.get()) * 100
    AtamaSoup_Total = int(AtamaSoup_sb.get()) * 450
    EgusiSoup_Total = int(EgusiSoup_sb.get()) * 480
    SweetChiliChicken_Total = int(SweetChiliChicken_sb.get()) * 1100
    GrilledChickenWings_Total = int(GrilledChickenWings_sb.get()) * 400
    FriedBeef_Total = int(FriedBeef_sb.get()) * 400
    FriedFish_Total = int(FriedFish_sb.get()) * 500
    BoiledEgg_Total = int(BoiledEgg_sb.get()) * 200
    SauteedSausages_Total = int(SauteedSausages_sb.get()) * 200
    Water_Total = int(Water_sb.get()) * 200
    GlassDrink_Total = int(GlassDrink_sb.get()) * 150
    PETDrink_Total = int(PETDrink_sb.get()) * 300
    PET_Total = int(PET_sb.get()) * 350
    GlassCannedMalt_Total = int(GlassCannedMalt_sb.get()) * 500
    FreshYo_Total = int(FreshYo_sb.get()) * 600
    PineappleJuice_Total = int(PineappleJuice_sb.get()) * 350
    MangoJuice_Total = int(MangoJuice_sb.get()) * 350
    ZoboDrink_Total = int(ZoboDrink_sb.get()) * 350

    Total_Billing = ( JollofRice_Total + CoconutRice_Total + JollofSpaghetti_Total + SavouryBeans_Total + RoastedSweetPotatoes_Total + FriedPlantain_Total + MixedVegetableSalad_Total + BoiledYam_Total + Eba_Total + PoundedYam_Total + Semo_Total + AtamaSoup_Total + EgusiSoup_Total + SweetChiliChicken_Total +
                    + GrilledChickenWings_Total + FriedBeef_Total + FriedFish_Total + BoiledEgg_Total + SauteedSausages_Total + Water_Total + GlassDrink_Total + PETDrink_Total + PET_Total + GlassCannedMalt_Total + FreshYo_Total + PineappleJuice_Total + MangoJuice_Total + ZoboDrink_Total)

    return Total_Billing



    #Creating Main Menu Page
root = tk.Tk()
root.geometry("900x800")
root.title("Cafeteria Page")
root.configure(bg='pink')


#Creating Labels for the Menu Title
label = tk.Label(root, text="PAU CAFETERIA MENU", font=('Times New Roman', 20, "bold"), bg='pink').grid(row=0,sticky=N,padx=250,pady=10)
Label(root, text="Please select a tasty dish", font=("Times New Roman", 14, "italic"), bg='pink').grid(row=1,sticky=N)


#Creating Rice & Pasta Category Labels
Rice_pasta_label = Label(root, text="RICE/PASTA", font=("Times New Roman", 14), bg='pink')
Rice_pasta_label.grid(row=2,sticky=W,padx=70,pady=20)


JollofRice_label = Label(root, text="Jollof Rice", font=("Times New Roman", 12,), padx=10, bg='pink')
JollofRice_label.grid(sticky=W)
JollofRice_sb = Spinbox(from_=0, to=100, width=5)
JollofRice_sb.grid(sticky=W,row=3, padx=230)
Jprice_label = Label(root, text="N350", bg='pink').grid(sticky=W,row=3,padx=190)



CoconutRice_label =  Label(root, text="Coconut Rice", font=("Times New Roman", 12), padx=10, bg='pink')
CoconutRice_label.grid(sticky=W)
CoconutRice_sb = Spinbox(from_=0, to=100, width=5)
CoconutRice_sb.grid(sticky=W,row=4, padx=230)
Cprice_label= Label(root, text="N350", bg='pink').grid(sticky=W,row=4,padx=190)


JollofSpaghetti_label =  Label(root, text="Jollof Spaghetti", font=("Times New Roman", 12), padx=10, bg='pink')
JollofSpaghetti_label.grid(sticky=W)
JollofSpaghetti_sb = Spinbox(from_=0, to=100, width=5)
JollofSpaghetti_sb.grid(sticky=W,row=5, padx=230)
Spaprice_label= Label(root, text="N350", bg='pink').grid(sticky=W,row=5,padx=190)


#Creating Side Dishes Category Label
SideDishes_label = Label(root, text="SIDE DISHES", font=("Times New Roman", 14), bg='pink')
SideDishes_label.grid(row=6,sticky=W,padx=30,pady=20)

SavouryBeans_label = Label(root, text="Savoury Beans", font=("Times New Roman", 12), padx=10, bg='pink')
SavouryBeans_label.grid(sticky=W)
SavouryBeans_sb = Spinbox(from_=0, to=100, width=5)
SavouryBeans_sb.grid(sticky=W,row=7, padx=230)
SBprice_label = Label(root, text="N350", bg='pink').grid(sticky=W,row=7,padx=190)

RoastedSweetPotatoes_label =  Label(root, text="Roasted Sweet Potatoes", font=("Times New Roman", 12), padx=10, bg='pink')
RoastedSweetPotatoes_label.grid(sticky=W)
RoastedSweetPotatoes_sb = Spinbox(from_=0, to=100, width=5)
RoastedSweetPotatoes_sb.grid(sticky=W,row=8, padx=230)
RSprice_label= Label(root, text="N300", bg='pink').grid(sticky=W,row=8,padx=190)

FriedPlantain_label =  Label(root, text="Fried Plantains", font=("Times New Roman", 12), padx=10, bg='pink')
FriedPlantain_label.grid(sticky=W, pady=3)
FriedPlantain_sb = Spinbox(from_=0, to=100, width=5)
FriedPlantain_sb.grid(sticky=W,row=9, padx=230)
Fprice_label= Label(root, text="N150", bg='pink').grid(sticky=W,row=9,padx=190)

MixedVegetableSalad_label =  Label(root, text="Mixed Vegetable Salad", font=("Times New Roman", 12), padx=10, bg='pink')
MixedVegetableSalad_label.grid(sticky=W)
MixedVegetableSalad_sb = Spinbox(from_=0, to=100, width=5)
MixedVegetableSalad_sb.grid(sticky=W,row=10, padx=230)
MVprice_label= Label(root, text="N150", bg='pink').grid(sticky=W,row=10,padx=190)

BoiledYam_label =  Label(root, text="Boiled Yam", font=("Times New Roman", 12), padx=10, bg='pink')
BoiledYam_label.grid(sticky=W)
BoiledYam_sb = Spinbox(from_=0, to=100, width=5)
BoiledYam_sb.grid(sticky=W,row=11, padx=230)
BYprice_label= Label(root, text="N150", bg='pink').grid(sticky=W,row=11,padx=190)


#Creating Soup & Swallow Category Labels
SoupandSwallow_label = Label(root, text="SOUP & SWALLOW", font=("Times New Roman", 14), bg='pink')
SoupandSwallow_label.grid(row=12,sticky=W,padx=30,pady=20)

Eba_label =  Label(root, text="Eba", font=("Times New Roman", 12), padx=10, bg='pink')
Eba_label.grid(sticky=W)
Eba_sb = Spinbox(from_=0, to=100, width=5)
Eba_sb.grid(sticky=W,row=13, padx=230)
Ebaprice_label= Label(root, text="N100", bg='pink').grid(sticky=W,row=13,padx=190)

PoundedYam_label =  Label(root, text="Pounded Yam", font=("Times New Roman", 12), padx=10, bg='pink')
PoundedYam_label.grid(sticky=W)
PoundedYam_sb = Spinbox(from_=0, to=100, width=5)
PoundedYam_sb.grid(sticky=W,row=14, padx=230)
PYprice_label= Label(root, text="N100", bg='pink').grid(sticky=W,row=14,padx=190)

Semo_label =  Label(root, text="Semo", font=("Times New Roman", 12), padx=10, bg='pink')
Semo_label.grid(sticky=W)
Semo_sb = Spinbox(from_=0, to=100, width=5)
Semo_sb.grid(sticky=W,row=15, padx=230)
Semoprice_label= Label(root, text="N100", bg='pink').grid(sticky=W,row=15,padx=190)

AtamaSoup_label =  Label(root, text="Atama Soup", font=("Times New Roman", 12), padx=10, bg='pink')
AtamaSoup_label.grid(sticky=W)
AtamaSoup_sb = Spinbox(from_=0, to=100, width=5)
AtamaSoup_sb.grid(sticky=W,row=16, padx=230)
ASprice_label= Label(root, text="N450", bg='pink').grid(sticky=W,row=16,padx=190)

EgusiSoup_label =  Label(root, text="Egusi Soup", font=("Times New Roman", 12), padx=10, bg='pink')
EgusiSoup_label.grid(sticky=W)
EgusiSoup_sb = Spinbox(from_=0, to=100, width=5)
EgusiSoup_sb.grid(sticky=W,row=17, padx=230)
ESprice_label= Label(root, text="N480", bg='pink').grid(sticky=W,row=17,padx=190)

#Creating the Protein Category Labels
Protein_label = Label(root, text="PROTEINS", font=("Times New Roman", 14), bg='pink')
Protein_label.grid(row=2,sticky=E,padx=70,pady=20)

SweetChiliChicken_label = Label(root, text="Sweet Chili Chicken", font=("Times New Roman", 12), bg='pink')
SweetChiliChicken_label.place(x=330, y=150)
SweetChiliChicken_sb = Spinbox(from_=0, to=100, width=5)
SweetChiliChicken_sb.place(x=590, y=155)
SCCprice_label = Label(root, text="N1100", bg='pink').grid(sticky=E,row=3,padx=5)

GrilledChickenWings_label = Label(root, text="Grilled Chicken Wings", font=("Times New Roman", 12), bg='pink')
GrilledChickenWings_label.place(x=330, y=180)
GrilledChickenWings_sb = Spinbox(from_=0, to=100, width=5)
GrilledChickenWings_sb.place(x=590, y=185)
GCWprice_label = Label(root, text="N400", bg='pink').grid(sticky=E, row=4, padx=5, pady=10)

FriedBeef_label = Label(root, text="Fried Beef", font=("Times New Roman", 12), bg='pink')
FriedBeef_label.place(x=332, y=214)
FriedBeef_sb = Spinbox(from_=0, to=100, width=5)
FriedBeef_sb.place(x=590, y=215)
FBprice_label = Label(root, text="N400", bg='pink').place(x=550,y=214)

FriedFish_label = Label(root, text="Fried Fish", font=("Times New Roman", 12), bg='pink')
FriedFish_label.place(x=332, y=245)
FriedFish_sb = Spinbox(from_=0, to=100, width=5)
FriedFish_sb.place(x=590, y=245)
FFprice_label = Label(root, text="N500", bg='pink').place(x=550,y=245)

BoiledEgg_label = Label(root, text="Boiled Egg", font=("Times New Roman", 12), bg='pink')
BoiledEgg_label.place(x=332, y=275)
BoiledEgg_sb = Spinbox(from_=0, to=100, width=5)
BoiledEgg_sb.place(x=590, y=275)
BEprice_label = Label(root, text="N200", bg='pink').place(x=550,y=275)

SauteedSausages_label = Label(root, text="Sauteed Sausages", font=("Times New Roman", 12), bg='pink')
SauteedSausages_label.place(x=332, y=305)
SauteedSausages_sb = Spinbox(from_=0, to=100, width=5)
SauteedSausages_sb.place(x=590, y=305)
SSprice_label = Label(root, text="N200", bg='pink').place(x=550,y=305)


#Creating Labels for Beverage Category
Beverage_label = Label(root, text="BEVERAGES", font=("Times New Roman", 14), bg='pink')
Beverage_label.grid(row=8,sticky=E,padx=70,pady=20)

Water_label = Label(root, text="Water", font=("Times New Roman", 12), bg='pink')
Water_label.place(x=332, y=400)
Water_sb = Spinbox(from_=0, to=100, width=5)
Water_sb.place(x=590, y=400)
Waterprice_label = Label(root, text="N200", bg='pink').place(x=550,y=400)

GlassDrink_label = Label(root, text="Glass Drink (35 cl)", font=("Times New Roman", 12), bg='pink')
GlassDrink_label.place(x=332, y=425)
GlassDrink_sb = Spinbox(from_=0, to=100, width=5)
GlassDrink_sb.place(x=590, y=425)
GlassDrinkprice_label = Label(root, text="N150", bg='pink').place(x=550,y=425)

PETDrink_label = Label(root, text="PET Drink (35 cl)", font=("Times New Roman", 12), bg='pink')
PETDrink_label.place(x=332, y=450)
PETDrink_sb = Spinbox(from_=0, to=100, width=5)
PETDrink_sb.place(x=590, y=450)
PETDrinkprice_label = Label(root, text="N300", bg='pink').place(x=550,y=450)

PET_label = Label(root, text="PET Drink (50 cl)", font=("Times New Roman", 12), bg='pink')
PET_label.place(x=332, y=470)
PET_sb = Spinbox(from_=0, to=100, width=5)
PET_sb.place(x=590, y=470)
Petprice_label = Label(root, text="N350", bg='pink').place(x=550,y=470)

GlassCannedMalt_label = Label(root, text="Glass Canned Malt", font=("Times New Roman", 12), bg='pink')
GlassCannedMalt_label.place(x=332, y=490)
GlassCannedMalt_sb = Spinbox(from_=0, to=100, width=5)
GlassCannedMalt_sb.place(x=590, y=490)
GCMprice_label = Label(root, text="N500", bg='pink').place(x=550,y=490)

FreshYo_label = Label(root, text="Fresh Yo", font=("Times New Roman", 12), bg='pink')
FreshYo_label.place(x=332, y=510)
FreshYo_sb = Spinbox(from_=0, to=100, width=5)
FreshYo_sb.place(x=590, y=510)
FreshYoprice_label = Label(root, text="N600", bg='pink').place(x=550,y=510)

PineappleJuice_label = Label(root, text="Pineappple Juice", font=("Times New Roman", 12), bg='pink')
PineappleJuice_label.place(x=332, y=530)
PineappleJuice_sb = Spinbox(from_=0, to=100, width=5)
PineappleJuice_sb.place(x=590, y=530)
PJprice_label = Label(root, text="N350", bg='pink').place(x=550,y=530)

MangoJuice_label = Label(root, text="Mango Juice", font=("Times New Roman", 12), bg='pink')
MangoJuice_label.place(x=332, y=550)
MangoJuice_sb = Spinbox(from_=0, to=100, width=5)
MangoJuice_sb.place(x=590, y=550)
MJprice_label = Label(root, text="N350", bg='pink').place(x=550,y=550)

ZoboDrink_label = Label(root, text="Zobo Drink", font=("Times New Roman", 12), bg='pink')
ZoboDrink_label.place(x=332, y=570)
ZoboDrink_sb = Spinbox(from_=0, to=100, width=5)
ZoboDrink_sb.place(x=590, y=570)
ZDprice_label = Label(root, text="N350", bg='pink').place(x=550,y=570)

user_label = Label(text="Enter Your Name:", font=('Times New Roman', 12), bg="pink")
user_label.place(x=410, y=615)
user_entry = Entry(root, font=('Times New Roman', 12), width=20)
user_entry.place(x=530, y=615)


#Create Submit Order Button
submit = Button(text="Submit Order", command=submit_order)
submit.place(x=540, y=660)

root.mainloop()
