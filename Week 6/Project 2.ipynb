# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk

#Create function for Computer Science Welcome Label

def welcomeMessage_1(department, name, score, credit):
    # Create a window
    window = tk.Toplevel(root)
    window.title("Computer Science Info Box")
    window.geometry("500x300")

    #Create Labels
    label_1 = tk.Label(window, text=f"Welcome to Computer Science Information Page {username}")
    label_1.pack()
    label_2 = tk.Label(window, text="Please input your details")
    label_2.pack()
    
    #Create Name Label
    name_label = tk.Label(root, text="NAME:")
    name_label.pack()
    name_entry = tk.Entry(root)
    name_entry.pack()

    #Create Jamb Score Label
    score_label = tk.Label(root, text="JAMB SCORE:")
    score_label.pack()
    score_entry = tk.Entry(root)
    score_entry.pack()

    #Create Credit Label
    credits_label = tk.Label(root, text="NUMBER OF CREDITS:")
    credits_label.pack()
    credits_entry = tk.Entry(root)
    credits_entry.pack()
    
    #Create Interview Label
    interview_var = tk.BooleanVar()
    interview_label = tk.Checkbutton(window, text="Passed Interview", variable=interview_var)
    interview_label.pack()

    #Create course info Button
    courseinfo_button = tk.Button(root, text="Submit", command=submit)
    courseinfo_button.pack()

    root.mainloop()

#Create a function for the Welcome Message for Mass Communication    
def welcomeMessage_2(department, name, score, credit):
    # Create a window
    window = tk.Toplevel(root)
    window.title("Mass Communications Info Box")
    window.geometry("500x300")

    label_1 = tk.Label(window, text=f"Welcome to Mass Communication Information Page {username}")
    label_1.pack()
    label_2 = tk.Label(window, text="Please input your details")
    label_2.pack()

    name_label = tk.Label(root, text="NAME:")
    name_label.pack()
    name_entry = tk.Entry(root)
    name_entry.pack()


    score_label = tk.Label(root, text="JAMB SCORE:")
    score_label.pack()
    score_entry = tk.Entry(root)
    score_entry.pack()


    credits_label = tk.Label(root, text="NUMBER OF CREDITS:")
    credits_label.pack()
    credits_entry = tk.Entry(root)
    credits_entry.pack()

    interview_var = tk.BooleanVar()
    interview_label = tk.Checkbutton(window, text="Passed Interview", variable=interview_var)
    interview_label.pack()

    courseinfo_button = tk.Button(root, text="Submit", command=submit)
    courseinfo_button.pack()





    root.mainloop()

#Creating functions for Department Submission
def deptsubmit():
        
    department = department_entry.get()
    name = name_entry.get()
    score = score_entry.get()
    credit = credit_entry.get()
    
    if department == "Computer Science":
        welcomeMessage_1(department, name, score, credit)
    elif department == "Mass Communication":
        welcomeMessage_2(department, name, score, credit)

#Creating function for Course Submission
def courseinfosubmit():
    
    name = name_entry.get()
    jamb_score = int(jambscore_entry.get())
    credits = int(credit_entry.get())
    passed_interview = interview_var.get()

    if jamb_score >= 250 and credits >= 5 and passed_interview:
        messagebox.showinfo("Admission Status", f"Congratulations {name}! You have been admitted into computer science.")
    else:
        messagebox.showinfo("Admission Status", f"Sorry, you are admitted into Computer Science.")
    
    

root = tk.Tk()
root.title("Student Department Login Page")
root.geometry("400x200")

department_label = tk.Label(root, text="Input Department:")
department_label.pack()
department_entry = tk.Entry(root)
department_entry.pack()
 
deptsubmit_button = tk.Button(root, text="Submit", command=deptsubmit)
deptsubmit_button.pack()

root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\kingu\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\kingu\AppData\Local\Temp\ipykernel_18504\1272273398.py", line 94, in deptsubmit
#     name = name_entry.get()
#            ^^^^^^^^^^
# NameError: name 'name_entry' is not defined
